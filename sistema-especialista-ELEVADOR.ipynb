# %% [markdown]
# # Regras para o Sistema Especialista ELEVADOR
#
#
# - Rule 1: IF pavimento atual for primeiro andar AND botão for apertado no primeiro andar THEN abrir a porta
# - Rule 2: IF pavimento atual for segundo andar AND botão for apertado no segundo andar THEN abrir a porta
# - Rule 3: IF pavimento atual for terceiro andar AND botão for apertado no terceiro andar THEN abrir a porta
# - Rule 4: IF pavimento atual for primeiro andar AND botão for apertado no segundo andar THEN ir para o segundo andar
# - Rule 5: IF pavimento atual for segundo andar AND botão for apertado no primeiro andar THEN ir para o primeiro andar
# - Rule 6: IF pavimento atual for segundo andar AND botão for apertado no terceiro andar THEN ir para o terceiro andar
# - Rule 7: IF pavimento atual for terceiro andar AND botão for apertado no segundo andar THEN ir para o segundo andar
# - Rule 8: IF pavimento atual for primeiro andar AND botão for apertado no terceiro andar THEN ir para o terceiro andar
# - Rule 9: IF pavimento atual for terceiro andar AND botão for apertado no primeiro andar THEN ir para o primeiro andar
# - Rule 10: IF pavimento atual for segundo andar AND botão for apertado no primeiro andar AND já estiver indo para o terceiro andar THEN lembrar de ir ao primeiro andar depois
# - Rule 11: IF pavimento atual for segundo andar AND botão for apertado no terceiro andar AND já estiver indo para o primeiro andar THEN lembrar de ir ao terceiro andar depois
# - Rule 12: IF pavimento atual for primeiro andar AND botão for apertado no segundo andar AND já estiver indo para o terceiro andar THEN lembrar de ir ao terceiro andar depois
# - Rule 13: IF pavimento atual for primeiro andar AND botão for apertado no terceiro andar AND já estiver indo para o segundo andar THEN lembrar de ir ao terceiro andar depois
# - Rule 14: IF pavimento atual for terceiro andar AND botão for apertado no primeiro andar AND já estiver indo para o segundo andar THEN lembrar de ir ao primeiro andar depois
# - Rule 15: IF pavimento atual for terceiro andar AND botão for apertado no segundo andar AND já estiver indo para o primeiro andar THEN lembrar de ir ao primeiro andar depois
#
# -------------------------------------------------------------------------------------------------------------------

# %%
def andar_atual(pavimento_atual):
    print("---- Você está no {} andar ----".format(pavimento_atual))
    return

# %%
def ir_para(botao):
    print("Próxima parada: {} andar".format(botao))
    print("Você chegou ao {} andar".format(botao))
    return

# %%
def abrir_a_porta():
    print("Abrindo a porta do elevador... Pode entrar.")
    return

# %%
def elevador(pavimento_atual, botao, destino):
    
            andar_atual(pavimento_atual)
            print("O botão foi apertado no andar: [1] [2] [3]")
            print("Pressione 4 para sair do elevador.")
            botao = int(input())
            if botao == 4:
                print("Você saiu do elevador.")
                return
            print("O destino anterior era: [1] [2] [3] ou nenhum [0]")
            destino = int(input())

            if pavimento_atual == 1 and botao == 1 and destino == 0:
                andar_atual(pavimento_atual)
                abrir_a_porta()
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
            
            elif pavimento_atual == 2 and botao == 2 and destino == 0: 
                andar_atual(pavimento_atual)
                abrir_a_porta()
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
                
            elif pavimento_atual == 3 and botao == 3 and destino == 0: 
                andar_atual(pavimento_atual)
                abrir_a_porta()
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)

            elif pavimento_atual == 1 and botao == 2 and destino == 0:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
                
            elif pavimento_atual == 1 and botao == 3 and destino == 0:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
            
            elif pavimento_atual == 2 and botao == 1 and destino == 0: 
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)            
                
            elif pavimento_atual == 2 and botao == 3 and destino == 0:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
            
            elif pavimento_atual == 3 and botao == 1 and destino == 0:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
            
            elif pavimento_atual == 3 and botao == 2 and destino == 0:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                elevador(pavimento_atual, botao, destino)
                
            elif pavimento_atual == 2 and botao == 1 and destino == 3:
                andar_atual(pavimento_atual)
                ir_para(destino)
                pavimento_atual = destino
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                destino = 0
                elevador(pavimento_atual, botao, destino)
                
            elif pavimento_atual == 2 and botao == 3 and destino == 1:
                andar_atual(pavimento_atual)
                ir_para(destino)
                pavimento_atual = destino
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                destino = 0
                elevador(pavimento_atual, botao, destino)
            
            elif pavimento_atual == 1 and botao == 2 and destino == 3:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                andar_atual(pavimento_atual)
                ir_para(destino)
                pavimento_atual = destino
                botao = 0
                destino = 0
                elevador(pavimento_atual, botao, destino)
            
            elif pavimento_atual == 1 and botao == 3 and destino == 2:
                andar_atual(pavimento_atual)
                ir_para(destino)
                pavimento_atual = destino
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                destino = 0
                elevador(pavimento_atual, botao, destino)
            
            
            elif pavimento_atual == 3 and botao == 1 and destino == 2:
                andar_atual(pavimento_atual)
                ir_para(destino)
                pavimento_atual = destino
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                botao = 0
                destino = 0
                elevador(pavimento_atual, botao, destino)
                
            elif pavimento_atual == 3 and botao == 2 and destino == 1:
                andar_atual(pavimento_atual)
                ir_para(botao)
                pavimento_atual = botao
                andar_atual(pavimento_atual)
                ir_para(destino)
                pavimento_atual = destino
                botao = 0
                destino = 0
                elevador(pavimento_atual, botao, destino)

# %%
elevador(1,1,0)
# Out:
# ---- Você está no 1 andar ----
# O botão foi apertado no andar: [1] [2] [3]
# Pressione 4 para sair do elevador.
# 2
# O destino anterior era: [1] [2] [3] ou nenhum [0]
# 3
# ---- Você está no 1 andar ----
# Próxima parada: 2 andar
# Você chegou ao 2 andar
# ---- Você está no 2 andar ----
# Próxima parada: 3 andar
# Você chegou ao 3 andar
# ---- Você está no 3 andar ----
# O botão foi apertado no andar: [1] [2] [3]
# Pressione 4 para sair do elevador.
# 2
# O destino anterior era: [1] [2] [3] ou nenhum [0]
# 1
# ---- Você está no 3 andar ----
# Próxima parada: 2 andar
# Você chegou ao 2 andar
# ---- Você está no 2 andar ----
# Próxima parada: 1 andar
# Você chegou ao 1 andar
# ---- Você está no 1 andar ----
# O botão foi apertado no andar: [1] [2] [3]
# Pressione 4 para sair do elevador.
# 2
# O destino anterior era: [1] [2] [3] ou nenhum [0]
# 3
# ---- Você está no 1 andar ----
# Próxima parada: 2 andar
# Você chegou ao 2 andar
# ---- Você está no 2 andar ----
# ...
